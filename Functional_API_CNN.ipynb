# %% [markdown]
# <a href="https://colab.research.google.com/github/intelligencethink/Practice/blob/master/Functional_API_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' Using Functional API to build CNN

~99.3% test accuracy
'''

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical


# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)
y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='relu')(inputs)
y = MaxPooling2D()(y)
y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='relu')(y)
y = MaxPooling2D()(y)
y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)

# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()

# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=20,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
print(score)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                5770
# =================================================================
# Total params: 80,266
# Trainable params: 80,266
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 469/469 [==============================] - 79s 168ms/step - loss: 0.2808 - accuracy: 0.9130 - val_loss: 0.0566 - val_accuracy: 0.9825
# Epoch 2/20
# 469/469 [==============================] - 78s 167ms/step - loss: 0.0749 - accuracy: 0.9772 - val_loss: 0.0344 - val_accuracy: 0.9894
# Epoch 3/20
# 469/469 [==============================] - 79s 168ms/step - loss: 0.0539 - accuracy: 0.9836 - val_loss: 0.0299 - val_accuracy: 0.9903
# Epoch 4/20
# 469/469 [==============================] - 77s 165ms/step - loss: 0.0414 - accuracy: 0.9873 - val_loss: 0.0379 - val_accuracy: 0.9866
# Epoch 5/20
# 469/469 [==============================] - 77s 165ms/step - loss: 0.0370 - accuracy: 0.9886 - val_loss: 0.0303 - val_accuracy: 0.9904
# Epoch 6/20
# 469/469 [==============================] - 77s 165ms/step - loss: 0.0326 - accuracy: 0.9898 - val_loss: 0.0277 - val_accuracy: 0.9906
# Epoch 7/20
# 469/469 [==============================] - 78s 166ms/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 0.0225 - val_accuracy: 0.9930
# Epoch 8/20
# 469/469 [==============================] - 77s 165ms/step - loss: 0.0254 - accuracy: 0.9916 - val_loss: 0.0216 - val_accuracy: 0.9924
# Epoch 9/20
# 469/469 [==============================] - 77s 164ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.0211 - val_accuracy: 0.9933
# Epoch 10/20
# 469/469 [==============================] - 77s 164ms/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 0.0217 - val_accuracy: 0.9931
# Epoch 11/20
# 469/469 [==============================] - 77s 164ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.0224 - val_accuracy: 0.9923
# Epoch 12/20
# 469/469 [==============================] - 77s 164ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.0254 - val_accuracy: 0.9914
# Epoch 13/20
# 469/469 [==============================] - 77s 163ms/step - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.0242 - val_accuracy: 0.9930
# Epoch 14/20
# 469/469 [==============================] - 77s 164ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.0214 - val_accuracy: 0.9937
# Epoch 15/20
# 469/469 [==============================] - 77s 165ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0249 - val_accuracy: 0.9930
# Epoch 16/20
# 469/469 [==============================] - 76s 162ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0259 - val_accuracy: 0.9927
# Epoch 17/20
# 469/469 [==============================] - 75s 161ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.0217 - val_accuracy: 0.9936
# Epoch 18/20
# 469/469 [==============================] - 76s 162ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.0237 - val_accuracy: 0.9937
# Epoch 19/20
# 469/469 [==============================] - 76s 161ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0266 - val_accuracy: 0.9926
# Epoch 20/20
# 469/469 [==============================] - 76s 162ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0242 - val_accuracy: 0.9930
#
# Test accuracy: 99.3%
# [0.02418406307697296, 0.9929999709129333]
